# %% [markdown]
# # 2025 COMP90042 Project
# *Make sure you change the file name with your group id.*

# %% [markdown]
# # Readme
# *If there is something to be noted for the marker, please mention here.*
#
# *If you are planning to implement a program with Object Oriented Programming style, please put those the bottom of this ipynb file*

# %% [markdown]
# # 1.DataSet Processing
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %% [markdown]
# ### a. Data loading and structure analysis

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# Loading JSON data
sns.set(style="whitegrid")
with open('../../data/train-claims.json', 'r') as f:
    train_data = json.load(f)

with open('../../data/dev-claims.json', 'r') as f:
    dev_data = json.load(f)

with open('../../data/test-claims-unlabelled.json', 'r') as f:
    test_data = json.load(f)

with open('../../data/evidence.json', 'r') as f:
    evidence_data = json.load(f)

# Constructing a DataFrame with a uniform structure
def json_to_df(data_dict, data_type):
    records = []
    for claim_id, item in data_dict.items():
        record = {
            'id': claim_id,
            'claim_text': item.get('claim_text', ''),
            'claim_label': item.get('claim_label', None),
            'evidences': item.get('evidences', []),
            'data_type': data_type
        }
        records.append(record)
    return pd.DataFrame(records)

df_train = json_to_df(train_data, "train")
df_dev = json_to_df(dev_data, "dev")
df_test = json_to_df(test_data, "test")  # test has no labels and evidences

# Combining train and dev data for analysis
df_all = pd.concat([df_train, df_dev], ignore_index=True)

# Adding satistics to the DataFrame
df_all['text_len'] = df_all['claim_text'].str.split().apply(len)
df_all['num_evidence'] = df_all['evidences'].apply(lambda x: len(x) if isinstance(x, list) else 0)
df_all
# Out:
#               id                                         claim_text  \
# 0     claim-1937  Not only is there no scientific evidence that ...
# 1      claim-126  El Niño drove record highs in global temperatu...
# 2     claim-2510             In 1946, PDO switched to a cool phase.
# 3     claim-2021  Weather Channel co-founder John Coleman provid...
# 4     claim-2449  "January 2008 capped a 12 month period of glob...
# ...          ...                                                ...
# 1377  claim-2400  'To suddenly label CO2 as a "pollutant" is a d...
# 1378   claim-204  after a natural orbitally driven warming, atmo...
# 1379  claim-1426  Many of the world’s coral reefs are already ba...
# 1380   claim-698  A recent study led by Lawrence Livermore Natio...
# 1381  claim-1021  The corals may save themselves, as many other ...
#
#           claim_label                                          evidences  \
# 0            DISPUTED  [evidence-442946, evidence-1194317, evidence-1...
# 1             REFUTES                [evidence-338219, evidence-1127398]
# 2            SUPPORTS                 [evidence-530063, evidence-984887]
# 3            DISPUTED  [evidence-1177431, evidence-782448, evidence-5...
# 4     NOT_ENOUGH_INFO  [evidence-1010750, evidence-91661, evidence-72...
# ...               ...                                                ...
# 1377          REFUTES  [evidence-409365, evidence-127519, evidence-85...
# 1378  NOT_ENOUGH_INFO  [evidence-368192, evidence-261690, evidence-20...
# 1379  NOT_ENOUGH_INFO  [evidence-1124018, evidence-995813, evidence-1...
# 1380          REFUTES                                  [evidence-660755]
# 1381         SUPPORTS                [evidence-242575, evidence-1175280]
#
#      data_type  text_len  num_evidence
# 0        train        24             3
# 1        train        17             2
# 2        train         8             2
# 3        train        16             5
# 4        train        19             5
# ...        ...       ...           ...
# 1377       dev        31             4
# 1378       dev        14             5
# 1379       dev        16             5
# 1380       dev        40             1
# 1381       dev        28             2
#
# [1382 rows x 7 columns]

# %%
df_test
# Out:
#              id                                         claim_text  \
# 0    claim-2967  The contribution of waste heat to the global c...
# 1     claim-979  “Warm weather worsened the most recent five-ye...
# 2    claim-1609  Greenland has only lost a tiny fraction of its...
# 3    claim-1020  “The global reef crisis does not necessarily m...
# 4    claim-2599  Small amounts of very active substances can ca...
# ..          ...                                                ...
# 148   claim-293  When the measuring equipment gets old and need...
# 149   claim-910  The cement, iron and steel, and petroleum refi...
# 150  claim-2815  A new peer-reviewed study on Surface Warming a...
# 151  claim-1652  The strong CO2 effect has been observed by man...
# 152  claim-1212  (In technical lingo, the so-called social cost...
#
#     claim_label evidences data_type
# 0          None        []      test
# 1          None        []      test
# 2          None        []      test
# 3          None        []      test
# 4          None        []      test
# ..          ...       ...       ...
# 148        None        []      test
# 149        None        []      test
# 150        None        []      test
# 151        None        []      test
# 152        None        []      test
#
# [153 rows x 5 columns]

# %%
# 1. label distribution
plt.figure(figsize=(7, 5))
ax = sns.countplot(data=df_all, x='claim_label')
plt.title('Overall Label Distribution')
plt.xlabel('Claim Label')
plt.ylabel('Count')

# Annotate each bar with the count
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
# 2. Claim text length distribution
plt.figure(figsize=(7, 5))
ax = sns.histplot(df_all['text_len'], bins=20, kde=True)
plt.title('Claim Text Length Distribution')
plt.xlabel('Number of Words')
plt.ylabel('Frequency')

# Annotate each bar with the count
for p in ax.patches:
    height = int(p.get_height())
    if height > 0:  # Only annotate bars with a height greater than 0
        ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
# 3. Evidence count distribution
plt.figure(figsize=(7, 5))
ax = sns.histplot(df_all['num_evidence'], bins=15, kde=False)
plt.title('Distribution of Evidence Count per Claim')
plt.xlabel('Number of Evidences')
plt.ylabel('Number of Claims')
plt.xticks(range(df_all['num_evidence'].min(), df_all['num_evidence'].max() + 1))  # Ensure integer ticks

# Annotate each bar with the count
for p in ax.patches:
    height = int(p.get_height())
    if height > 0:  # Only annotate bars with a height greater than 0
        ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                    ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# ### b. Text data pre-processing

# %%
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')

# Initialize NLTK components
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Get WordNet POS tag from NLTK POS tag
def get_wordnet_pos(nltk_pos_tag):
    if nltk_pos_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_pos_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_pos_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Main preprocessing function
def preprocess_text(text):
    # 1. normalize text (lowercase, remove extra spaces)
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()

    # 2. tokenization
    tokens = word_tokenize(text)

    # 3. filter out stop words and non-alphanumeric tokens
    def is_valid_token(t):
        return any(c.isalnum() for c in t)

    tokens = [t for t in tokens if is_valid_token(t) and t not in stop_words]

    # 4. Lemmatization
    pos_tags = nltk.pos_tag(tokens)
    lemmas = [lemmatizer.lemmatize(w, get_wordnet_pos(pos)) for w, pos in pos_tags]

    return lemmas

# Preprocess the claim text
df_all['claim_tokens'] = df_all['claim_text'].apply(preprocess_text)
df_all
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#               id                                         claim_text  \
# 0     claim-1937  Not only is there no scientific evidence that ...
# 1      claim-126  El Niño drove record highs in global temperatu...
# 2     claim-2510             In 1946, PDO switched to a cool phase.
# 3     claim-2021  Weather Channel co-founder John Coleman provid...
# 4     claim-2449  "January 2008 capped a 12 month period of glob...
# ...          ...                                                ...
# 1377  claim-2400  'To suddenly label CO2 as a "pollutant" is a d...
# 1378   claim-204  after a natural orbitally driven warming, atmo...
# 1379  claim-1426  Many of the world’s coral reefs are already ba...
# 1380   claim-698  A recent study led by Lawrence Livermore Natio...
# 1381  claim-1021  The corals may save themselves, as many other ...
#
#           claim_label                                          evidences  \
# 0            DISPUTED  [evidence-442946, evidence-1194317, evidence-1...
# 1             REFUTES                [evidence-338219, evidence-1127398]
# 2            SUPPORTS                 [evidence-530063, evidence-984887]
# 3            DISPUTED  [evidence-1177431, evidence-782448, evidence-5...
# 4     NOT_ENOUGH_INFO  [evidence-1010750, evidence-91661, evidence-72...
# ...               ...                                                ...
# 1377          REFUTES  [evidence-409365, evidence-127519, evidence-85...
# 1378  NOT_ENOUGH_INFO  [evidence-368192, evidence-261690, evidence-20...
# 1379  NOT_ENOUGH_INFO  [evidence-1124018, evidence-995813, evidence-1...
# 1380          REFUTES                                  [evidence-660755]
# 1381         SUPPORTS                [evidence-242575, evidence-1175280]
#
#      data_type  text_len  num_evidence  \
# 0        train        24             3
# 1        train        17             2
# 2        train         8             2
# 3        train        16             5
# 4        train        19             5
# ...        ...       ...           ...
# 1377       dev        31             4
# 1378       dev        14             5
# 1379       dev        16             5
# 1380       dev        40             1
# 1381       dev        28             2
#
#                                            claim_tokens
# 0     [scientific, evidence, co2, pollutant, high, c...
# 1     [el, niño, drove, record, highs, global, tempe...
# 2                      [1946, pdo, switch, cool, phase]
# 3     [weather, channel, co-founder, john, coleman, ...
# 4     [january, 2008, cap, 12, month, period, global...
# ...                                                 ...
# 1377  ['to, suddenly, label, co2, pollutant, disserv...
# 1378  [natural, orbitally, driven, warm, atmospheric...
# 1379  [many, world, coral, reef, already, barren, st...
# 1380  [recent, study, lead, lawrence, livermore, nat...
# 1381  [coral, may, save, many, creature, attempt, mo...
#
# [1382 rows x 8 columns]

# %%
# Print claim_text and claim_tokens for a single row in df_all
row_index = 0 # change for testing
print("Claim Text:", df_all.loc[row_index, 'claim_text'])
print("Claim Tokens:", df_all.loc[row_index, 'claim_tokens'])
# Out:
# Claim Text: Not only is there no scientific evidence that CO2 is a pollutant, higher CO2 concentrations actually help ecosystems support more plant and animal life.
# Claim Tokens: ['scientific', 'evidence', 'co2', 'pollutant', 'high', 'co2', 'concentration', 'actually', 'help', 'ecosystems', 'support', 'plant', 'animal', 'life']

# %%
# Preprocess the evidence data(it will take about 10 minutes, just run it once)
from tqdm import tqdm

evidence_data_tokens = {
    evid_id: preprocess_text(text) for evid_id, text in tqdm(evidence_data.items())
}

# %%
import os
import json

# Save the preprocessed evidence data tokens to a JSON file
os.makedirs('../../data', exist_ok=True)
save_path = '../../data/evidence_data_tokens.json'

with open(save_path, 'w', encoding='utf-8') as f:
    json.dump(evidence_data_tokens, f)

print(f"Saved preprocessed evidence tokens to: {save_path}")

# %%
import json

# Load the preprocessed evidence data tokens from the JSON file
with open('../../data/evidence_data_tokens.json', 'r', encoding='utf-8') as f:
    evidence_data_tokens = json.load(f)

# Print the first evidence ID and its preprocessed tokens
first_id = list(evidence_data_tokens.keys())[0]
print(f"Evidence ID: {first_id}")
print("\nPreprocessed Tokens:")
print(evidence_data_tokens[first_id])
original_text = evidence_data[first_id]
print("Original Text:")
print(original_text)
# Out:
# Evidence ID: evidence-0
#
# Preprocessed Tokens:
# ['john', 'bennet', 'lawes', 'english', 'entrepreneur', 'agricultural', 'scientist']
# Original Text:
# John Bennet Lawes, English entrepreneur and agricultural scientist

# %%
# Preprocess the claim text in train and dev data
df_train['claim_tokens'] = df_train['claim_text'].apply(preprocess_text)
df_dev['claim_tokens'] = df_dev['claim_text'].apply(preprocess_text)
df_train
# Out:
#               id                                         claim_text  \
# 0     claim-1937  Not only is there no scientific evidence that ...
# 1      claim-126  El Niño drove record highs in global temperatu...
# 2     claim-2510             In 1946, PDO switched to a cool phase.
# 3     claim-2021  Weather Channel co-founder John Coleman provid...
# 4     claim-2449  "January 2008 capped a 12 month period of glob...
# ...          ...                                                ...
# 1223  claim-1504  Climate scientists say that aspects of the cas...
# 1224   claim-243  In its 5th assessment report in 2013, the IPCC...
# 1225  claim-2302  Since the mid 1970s, global temperatures have ...
# 1226   claim-502  But abnormal temperature spikes in February an...
# 1227  claim-3093  Sending oscillating microwaves from an antenna...
#
#           claim_label                                          evidences  \
# 0            DISPUTED  [evidence-442946, evidence-1194317, evidence-1...
# 1             REFUTES                [evidence-338219, evidence-1127398]
# 2            SUPPORTS                 [evidence-530063, evidence-984887]
# 3            DISPUTED  [evidence-1177431, evidence-782448, evidence-5...
# 4     NOT_ENOUGH_INFO  [evidence-1010750, evidence-91661, evidence-72...
# ...               ...                                                ...
# 1223         SUPPORTS  [evidence-1055682, evidence-1047356, evidence-...
# 1224         SUPPORTS                                  [evidence-916755]
# 1225  NOT_ENOUGH_INFO  [evidence-403673, evidence-889933, evidence-11...
# 1226  NOT_ENOUGH_INFO  [evidence-97375, evidence-562427, evidence-521...
# 1227         SUPPORTS  [evidence-971105, evidence-457769, evidence-29...
#
#      data_type                                       claim_tokens
# 0        train  [scientific, evidence, co2, pollutant, high, c...
# 1        train  [el, niño, drove, record, highs, global, tempe...
# 2        train                   [1946, pdo, switch, cool, phase]
# 3        train  [weather, channel, co-founder, john, coleman, ...
# 4        train  [january, 2008, cap, 12, month, period, global...
# ...        ...                                                ...
# 1223     train  [climate, scientist, say, aspect, case, hurric...
# 1224     train  [5th, assessment, report, 2013, ipcc, estimate...
# 1225     train  [since, mid, 1970s, global, temperature, warm,...
# 1226     train  [abnormal, temperature, spike, february, earli...
# 1227     train  [send, oscillate, microwave, antenna, inside, ...
#
# [1228 rows x 6 columns]

# %% [markdown]
# ### c. “Digitizing” data to prepare for training models

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import random

def get_hard_negatives(claim_text, gold_ids, evidence_data, top_k=100, candidate_pool_size=1000, seed=42):
    """
    Select the top_k most similar non-gold evidences from the candidate pool as hard negatives.
    """
    random.seed(seed)

    # All non-gold candidates
    all_candidates = [(eid, text) for eid, text in evidence_data.items() if eid not in gold_ids]

    # Limiting the candidate pool size
    if len(all_candidates) > candidate_pool_size:
        all_candidates = random.sample(all_candidates, candidate_pool_size)

    corpus = [claim_text] + [text for _, text in all_candidates]
    evid_ids = [eid for eid, _ in all_candidates]

    # TF-IDF similarity calculation
    vec = TfidfVectorizer().fit_transform(corpus)
    sims = cosine_similarity(vec[0:1], vec[1:]).flatten()
    top_indices = sims.argsort()[-top_k:][::-1]

    return [evid_ids[i] for i in top_indices]

# %%
import random
import pandas as pd
from tqdm import tqdm

def construct_training_pairs(df_claims, evidence_token_dict, evidence_data, seed=42):
    """
    Construct training sample pairs, including:
    - Positive samples: claim and its gold evidence;
    - Negative samples: 25 hard negatives + 25 random negatives.
    """
    random.seed(seed)
    pairs = []
    all_evidence_ids = list(evidence_token_dict.keys())

    for _, row in tqdm(df_claims.iterrows(), total=len(df_claims), desc="Constructing pairs"):
        claim_id = row['id']
        claim_tokens = row['claim_tokens']
        gold_ids = row['evidences']
        claim_text = ' '.join(claim_tokens)

        # Positive sample pair
        for evid_id in gold_ids:
            if evid_id in evidence_token_dict:
                pairs.append({
                    'claim_id': claim_id,
                    'claim_tokens': claim_tokens,
                    'evidence_id': evid_id,
                    'evidence_tokens': evidence_token_dict[evid_id],
                    'label': 1
                })

        # Non-gold candidates
        non_gold = list(set(all_evidence_ids) - set(gold_ids))

        # Fixed 125 hard negatives
        hard_neg_ids = get_hard_negatives(
            claim_text,
            gold_ids,
            evidence_data,
            top_k=min(125, len(non_gold)),
            candidate_pool_size=1000,
            seed=seed
        )

        # Fixed 125 random negatives
        remaining_neg_pool = list(set(non_gold) - set(hard_neg_ids))
        random_neg_ids = random.sample(remaining_neg_pool, min(125, len(remaining_neg_pool)))

        # Merge negative samples
        negative_ids = hard_neg_ids + random_neg_ids

        for evid_id in negative_ids:
            if evid_id in evidence_token_dict:
                pairs.append({
                    'claim_id': claim_id,
                    'claim_tokens': claim_tokens,
                    'evidence_id': evid_id,
                    'evidence_tokens': evidence_token_dict[evid_id],
                    'label': 0
                })

    return pd.DataFrame(pairs)



# Construct training sample pairs
train_pairs = construct_training_pairs(
    df_claims=df_train,
    evidence_token_dict=evidence_data_tokens,
    evidence_data=evidence_data
)
# Out:
# Constructing pairs: 100%|██████████| 1228/1228 [14:40<00:00,  1.39it/s]

# %%
import matplotlib.pyplot as plt

#len of claim token 
train_pairs['claim_len'] = train_pairs['claim_tokens'].apply(len)

# len Evidence token
train_pairs['evidence_len'] = train_pairs['evidence_tokens'].apply(len)

# Merge Visualization
plt.hist(train_pairs['claim_len'], bins=30, alpha=0.5, label='claim')
plt.hist(train_pairs['evidence_len'], bins=30, alpha=0.5, label='evidence')

# Mark the highest value
max_claim_len = train_pairs['claim_len'].max()
max_evidence_len = train_pairs['evidence_len'].max()

plt.axvline(max_claim_len, color='blue', linestyle='dashed', linewidth=1, label=f'Max Claim Length: {max_claim_len}')
plt.axvline(max_evidence_len, color='orange', linestyle='dashed', linewidth=1, label=f'Max Evidence Length: {max_evidence_len}')

# Mark the value with the highest frequency
most_frequent_claim_len = train_pairs['claim_len'].value_counts().idxmax()
most_frequent_evidence_len = train_pairs['evidence_len'].value_counts().idxmax()

plt.axvline(most_frequent_claim_len, color='blue', linestyle='solid', linewidth=1, label=f'Most Frequent Claim Length: {most_frequent_claim_len}')
plt.axvline(most_frequent_evidence_len, color='orange', linestyle='solid', linewidth=1, label=f'Most Frequent Evidence Length: {most_frequent_evidence_len}')

plt.xlabel('Token Length')
plt.ylabel('Count')
plt.title('Token Length Distribution')
plt.legend()
plt.show()

# Drop the length columns after visualization
train_pairs = train_pairs.drop(columns=['claim_len', 'evidence_len'])

# %%
from collections import Counter

# Step 1: Building a vocabulary
def build_vocab(train_df, min_freq=1):
    counter = Counter()

    for tokens in train_df['claim_tokens'].tolist() + train_df['evidence_tokens'].tolist():
        counter.update(tokens)

    vocab = {"<PAD>": 0, "<UNK>": 1}
    idx = 2
    for word, freq in counter.items():
        if freq >= min_freq:
            vocab[word] = idx
            idx += 1

    return vocab

# Step 2: tokens → index
def tokens_to_indices(tokens, vocab):
    return [vocab.get(t, vocab["<UNK>"]) for t in tokens]

# Step 3: padding
def pad_sequence(indices, max_len, pad_value=0):
    if len(indices) >= max_len:
        return indices[:max_len]
    else:
        return indices + [pad_value] * (max_len - len(indices))

# Step 4: Apply to train_pairs
MAX_LEN_CLAIM = 40
MAX_LEN_EVIDENCE = 190

# Build vocabulary with train_pairs
vocab = build_vocab(train_pairs)

# Perform token → index → ​​padding
train_pairs['claim_indices'] = train_pairs['claim_tokens'].apply(
    lambda x: pad_sequence(tokens_to_indices(x, vocab), MAX_LEN_CLAIM))

train_pairs['evidence_indices'] = train_pairs['evidence_tokens'].apply(
    lambda x: pad_sequence(tokens_to_indices(x, vocab), MAX_LEN_EVIDENCE))

train_pairs
# Out:
#           claim_id                                       claim_tokens  \
# 0       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 1       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 2       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 3       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 4       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# ...            ...                                                ...
# 311117  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311118  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311119  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311120  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311121  claim-3093  [send, oscillate, microwave, antenna, inside, ...
#
#              evidence_id                                    evidence_tokens  \
# 0        evidence-442946  [high, concentration, 100, time, atmospheric, ...
# 1       evidence-1194317  [plant, grow, much, 50, percent, faster, conce...
# 2         evidence-12171  [high, carbon, dioxide, concentration, favoura...
# 3        evidence-761227  [school, form, consolidation, six, high, schoo...
# 4        evidence-242072               [sex, clean, underside, plant, leaf]
# ...                  ...                                                ...
# 311117   evidence-248663     [impactor, estimate, 200–500, meter, diameter]
# 311118   evidence-626048  [robert, james, henderson, 15, august, 1877, 2...
# 311119    evidence-50524  [continue, ongoing, fundraise, big, brother, b...
# 311120  evidence-1104701  [seem, participate, one, engagement, french, s...
# 311121   evidence-615213  [many, lirgs, ulirgs, show, interaction, disru...
#
#         label                                      claim_indices  \
# 0           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 1           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 2           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 3           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 4           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# ...       ...                                                ...
# 311117      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311118      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311119      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311120      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311121      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
#
#                                          evidence_indices
# 0       [6, 7, 404, 55, 118, 7, 350, 288, 289, 1945, 1...
# 1       [12, 245, 100, 907, 313, 1892, 7, 704, 802, 33...
# 2       [6, 288, 289, 7, 3366, 946, 12, 2218, 3367, 39...
# 3       [2121, 537, 3368, 614, 6, 2121, 1808, 3317, 33...
# 4       [3376, 936, 3377, 12, 1568, 0, 0, 0, 0, 0, 0, ...
# ...                                                   ...
# 311117  [9990, 496, 9991, 1134, 9633, 0, 0, 0, 0, 0, 0...
# 311118  [2651, 924, 9654, 276, 3017, 5158, 303, 2613, ...
# 311119  [1990, 1888, 6227, 1083, 3737, 1083, 6228, 9, ...
# 311120  [491, 4721, 940, 1906, 4225, 1728, 13731, 0, 0...
# 311121  [1078, 11492, 11493, 116, 10697, 2260, 0, 0, 0...
#
# [311122 rows x 7 columns]

# %%
# Save train_pairs as JSON, one sample per line
train_pairs.to_json("../../data/train_pairs.json", orient="records", lines=True, force_ascii=False)

print("train_pairs has been successfully saved as a JSON file：../../data/train_pairs.json")

# Loading the JSON file
train_pairs = pd.read_json("../../data/train_pairs.json", orient="records", lines=True)
train_pairs
# Out:
# train_pairs has been successfully saved as a JSON file：../../data/train_pairs.json
#           claim_id                                       claim_tokens  \
# 0       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 1       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 2       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 3       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 4       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# ...            ...                                                ...
# 311117  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311118  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311119  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311120  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311121  claim-3093  [send, oscillate, microwave, antenna, inside, ...
#
#              evidence_id                                    evidence_tokens  \
# 0        evidence-442946  [high, concentration, 100, time, atmospheric, ...
# 1       evidence-1194317  [plant, grow, much, 50, percent, faster, conce...
# 2         evidence-12171  [high, carbon, dioxide, concentration, favoura...
# 3        evidence-761227  [school, form, consolidation, six, high, schoo...
# 4        evidence-242072               [sex, clean, underside, plant, leaf]
# ...                  ...                                                ...
# 311117   evidence-248663     [impactor, estimate, 200–500, meter, diameter]
# 311118   evidence-626048  [robert, james, henderson, 15, august, 1877, 2...
# 311119    evidence-50524  [continue, ongoing, fundraise, big, brother, b...
# 311120  evidence-1104701  [seem, participate, one, engagement, french, s...
# 311121   evidence-615213  [many, lirgs, ulirgs, show, interaction, disru...
#
#         label                                      claim_indices  \
# 0           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 1           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 2           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 3           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 4           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# ...       ...                                                ...
# 311117      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311118      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311119      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311120      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311121      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
#
#                                          evidence_indices
# 0       [6, 7, 404, 55, 118, 7, 350, 288, 289, 1945, 1...
# 1       [12, 245, 100, 907, 313, 1892, 7, 704, 802, 33...
# 2       [6, 288, 289, 7, 3366, 946, 12, 2218, 3367, 39...
# 3       [2121, 537, 3368, 614, 6, 2121, 1808, 3317, 33...
# 4       [3376, 936, 3377, 12, 1568, 0, 0, 0, 0, 0, 0, ...
# ...                                                   ...
# 311117  [9990, 496, 9991, 1134, 9633, 0, 0, 0, 0, 0, 0...
# 311118  [2651, 924, 9654, 276, 3017, 5158, 303, 2613, ...
# 311119  [1990, 1888, 6227, 1083, 3737, 1083, 6228, 9, ...
# 311120  [491, 4721, 940, 1906, 4225, 1728, 13731, 0, 0...
# 311121  [1078, 11492, 11493, 116, 10697, 2260, 0, 0, 0...
#
# [311122 rows x 7 columns]

# %% [markdown]
# # 2. Model Implementation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %% [markdown]
# ### a. Convert training samples (claim + evidence + label) into a format that PyTorch can read in batches and feed into model training

# %%
# Loading the JSON file to start
import pandas as pd
train_pairs = pd.read_json("../../data/train_pairs.json", orient="records", lines=True)
train_pairs
# Out:
#           claim_id                                       claim_tokens  \
# 0       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 1       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 2       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 3       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# 4       claim-1937  [scientific, evidence, co2, pollutant, high, c...
# ...            ...                                                ...
# 311117  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311118  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311119  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311120  claim-3093  [send, oscillate, microwave, antenna, inside, ...
# 311121  claim-3093  [send, oscillate, microwave, antenna, inside, ...
#
#              evidence_id                                    evidence_tokens  \
# 0        evidence-442946  [high, concentration, 100, time, atmospheric, ...
# 1       evidence-1194317  [plant, grow, much, 50, percent, faster, conce...
# 2         evidence-12171  [high, carbon, dioxide, concentration, favoura...
# 3        evidence-761227  [school, form, consolidation, six, high, schoo...
# 4        evidence-242072               [sex, clean, underside, plant, leaf]
# ...                  ...                                                ...
# 311117   evidence-248663     [impactor, estimate, 200–500, meter, diameter]
# 311118   evidence-626048  [robert, james, henderson, 15, august, 1877, 2...
# 311119    evidence-50524  [continue, ongoing, fundraise, big, brother, b...
# 311120  evidence-1104701  [seem, participate, one, engagement, french, s...
# 311121   evidence-615213  [many, lirgs, ulirgs, show, interaction, disru...
#
#         label                                      claim_indices  \
# 0           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 1           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 2           1  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 3           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# 4           0  [2, 3, 4, 5, 6, 4, 7, 8, 9, 10, 11, 12, 13, 14...
# ...       ...                                                ...
# 311117      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311118      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311119      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311120      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
# 311121      0  [1698, 2139, 3348, 3349, 3350, 3351, 3352, 909...
#
#                                          evidence_indices
# 0       [6, 7, 404, 55, 118, 7, 350, 288, 289, 1945, 1...
# 1       [12, 245, 100, 907, 313, 1892, 7, 704, 802, 33...
# 2       [6, 288, 289, 7, 3366, 946, 12, 2218, 3367, 39...
# 3       [2121, 537, 3368, 614, 6, 2121, 1808, 3317, 33...
# 4       [3376, 936, 3377, 12, 1568, 0, 0, 0, 0, 0, 0, ...
# ...                                                   ...
# 311117  [9990, 496, 9991, 1134, 9633, 0, 0, 0, 0, 0, 0...
# 311118  [2651, 924, 9654, 276, 3017, 5158, 303, 2613, ...
# 311119  [1990, 1888, 6227, 1083, 3737, 1083, 6228, 9, ...
# 311120  [491, 4721, 940, 1906, 4225, 1728, 13731, 0, 0...
# 311121  [1078, 11492, 11493, 116, 10697, 2260, 0, 0, 0...
#
# [311122 rows x 7 columns]

# %%
import torch
from torch.utils.data import Dataset
class TripletRetrievalDataset(Dataset):
    def __init__(self, df):
        self.triplets = []
        grouped = df.groupby('claim_id')

        for claim_id, group in grouped:
            pos_rows = group[group['label'] == 1]
            neg_rows = group[group['label'] == 0]

            if len(pos_rows) == 0 or len(neg_rows) == 0:
                continue

            for _, pos in pos_rows.iterrows():
                for _, neg in neg_rows.sample(n=1).iterrows():
                    self.triplets.append((
                        pos['claim_indices'],
                        pos['evidence_indices'],
                        neg['evidence_indices']
                    ))

    def __len__(self):
        return len(self.triplets)

    def __getitem__(self, idx):
        claim, pos_e, neg_e = self.triplets[idx]
        return {
            "claim": torch.tensor(claim, dtype=torch.long),
            "pos_evidence": torch.tensor(pos_e, dtype=torch.long),
            "neg_evidence": torch.tensor(neg_e, dtype=torch.long)
        }

# %%
from torch.utils.data import DataLoader

# # Create a DataLoader for batching and shuffling the training data
triplet_dataset = TripletRetrievalDataset(train_pairs)
train_loader = DataLoader(triplet_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### b. Defining the LSTM Model

# %%
# 1. Model structure: LSTM-based Matching Model
import torch
import torch.nn as nn
import torch.nn.functional as F

class LSTMRetrievalModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim=100, hidden_dim=128):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 8, 1)

    def encode(self, x):
        emb = self.embedding(x)
        output, _ = self.lstm(emb)
        pooled, _ = torch.max(output, dim=1)
        return pooled

    def forward(self, claim, evidence):
        c = self.encode(claim)
        e = self.encode(evidence)
        combined = torch.cat([c, e, torch.abs(c - e), c * e], dim=1)
        out = self.fc(combined).squeeze(1)
        return out

# %%
# 2. Initialize the model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = LSTMRetrievalModel(vocab_size=len(vocab), embedding_dim=100, hidden_dim=128).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MarginRankingLoss(margin=1.0)

# %%
# 3.Setting up training components + training loop
from torch.optim import Adam
from tqdm import tqdm

def train_one_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0.0

    for batch in tqdm(dataloader, desc="Training"):
        claim = batch['claim'].to(device)
        pos_evidence = batch['pos_evidence'].to(device)
        neg_evidence = batch['neg_evidence'].to(device)

        pos_score = model(claim, pos_evidence)
        neg_score = model(claim, neg_evidence)

        # The goal is: pos_score > neg_score
        target = torch.ones_like(pos_score)
        loss = criterion(pos_score, neg_score, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
EPOCHS = 10
for epoch in range(1, EPOCHS + 1):
    avg_loss = train_one_epoch(model, train_loader, optimizer, criterion)
    print(f"Epoch {epoch}/{EPOCHS} - Avg Loss: {avg_loss:.4f}")
# Out:
# Training: 100%|██████████| 129/129 [00:01<00:00, 70.87it/s]
# Epoch 1/10 - Avg Loss: 0.3197
# Training: 100%|██████████| 129/129 [00:01<00:00, 80.03it/s]
# Epoch 2/10 - Avg Loss: 0.0577
# Training: 100%|██████████| 129/129 [00:01<00:00, 79.79it/s]
# Epoch 3/10 - Avg Loss: 0.0115
# Training: 100%|██████████| 129/129 [00:01<00:00, 79.86it/s]
# Epoch 4/10 - Avg Loss: 0.0018
# Training: 100%|██████████| 129/129 [00:01<00:00, 79.78it/s]
# Epoch 5/10 - Avg Loss: 0.0004
# Training: 100%|██████████| 129/129 [00:01<00:00, 78.74it/s]
# Epoch 6/10 - Avg Loss: 0.0004
# Training: 100%|██████████| 129/129 [00:01<00:00, 80.03it/s]
# Epoch 7/10 - Avg Loss: 0.0002
# Training: 100%|██████████| 129/129 [00:01<00:00, 78.96it/s]
# Epoch 8/10 - Avg Loss: 0.0001
# Training: 100%|██████████| 129/129 [00:01<00:00, 78.81it/s]
# Epoch 9/10 - Avg Loss: 0.0002
# Training: 100%|██████████| 129/129 [00:01<00:00, 78.28it/s]
# Epoch 10/10 - Avg Loss: 0.0005

# %%
import os
model_save_path = os.path.join(os.getcwd(), "model_final.pt")
torch.save(model.state_dict(), model_save_path)
print(f"Model saved to：{model_save_path}")
# Out:
# Model saved to：d:\Academic_Stuff\Coding_Save\notebooks\NLP\COMP90042_2025_A3\code_files\ximingwan\model_final.pt

# %% [markdown]
# # 3.Testing and Evaluation
# (You can add as many code blocks and text blocks as you need. However, YOU SHOULD NOT MODIFY the section title)

# %%
# Rebuilding the model structure
model = LSTMRetrievalModel(vocab_size=len(vocab), embedding_dim=100, hidden_dim=128)

# Load the trained parameters
import os
model_path = os.path.join(os.getcwd(), "model_final.pt")
model.load_state_dict(torch.load(model_path))
model.to(device)
model.eval()
# Out:
# LSTMRetrievalModel(
#   (embedding): Embedding(27104, 100, padding_idx=0)
#   (lstm): LSTM(100, 128, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=1024, out_features=1, bias=True)
# )

# %%
import json
import pandas as pd
import torch
from tqdm import tqdm

def predict_and_export_from_json(json_path, model, vocab, evidence_dict,
                                 top_k=6, max_len_claim=40, max_len_evidence=190,
                                 save_path="predictions.json", batch_size=1024):
    """
    First encode all evidences, then vectorize and calculate the matching score for each claim
    """
    device = next(model.parameters()).device
    model.eval()

    # Step 1: Read claim JSON to DataFrame
    with open(json_path, 'r') as f:
        raw_data = json.load(f)
    df = json_to_df(raw_data, data_type="unknown")
    df['claim_tokens'] = df['claim_text'].apply(preprocess_text)

    # Step 2: Encode all evidences to tensor
    evid_ids = list(evidence_dict.keys())
    evid_tensor_list = [
        pad_sequence(tokens_to_indices(evidence_dict[eid], vocab), max_len_evidence)
        for eid in evid_ids
    ]
    evidence_tensor = torch.tensor(evid_tensor_list, dtype=torch.long).to(device)

    # Step 3: Batch encode evidences
    with torch.no_grad():
        evidence_vecs = []
        for i in tqdm(range(0, len(evidence_tensor), batch_size), desc="Encoding evidences"):
            batch = evidence_tensor[i:i+batch_size]
            batch_vec = model.encode(batch)
            evidence_vecs.append(batch_vec)
        evidence_vecs = torch.cat(evidence_vecs, dim=0)

    # Step 4: Calculate the matching score of all evidence for each claim vectorization
    output_dict = {}
    for _, row in tqdm(df.iterrows(), total=len(df), desc="Scoring claims"):
        claim_id = row['id']
        claim_tokens = row['claim_tokens']
        claim_idx = pad_sequence(tokens_to_indices(claim_tokens, vocab), max_len_claim)
        claim_tensor = torch.tensor([claim_idx], dtype=torch.long).to(device)

        with torch.no_grad():
            claim_vec = model.encode(claim_tensor)
            c = claim_vec.expand(evidence_vecs.size(0), -1)
            e = evidence_vecs
            combined = torch.cat([c, e, torch.abs(c - e), c * e], dim=1)
            scores = torch.sigmoid(model.fc(combined).squeeze(1))

        topk_evid = [eid for eid, _ in sorted(zip(evid_ids, scores.tolist()), key=lambda x: x[1], reverse=True)[:top_k]]

        output_dict[claim_id] = {
            "claim_label": row.get("claim_label", "SUPPORTS"),
            "evidences": topk_evid
        }

    # Step 5: Save as JSON
    with open(save_path, 'w') as f:
        json.dump(output_dict, f, indent=2)

    print(f"Prediction results saved to：{save_path}")

# %%
predict_and_export_from_json(
    json_path="../../data/dev-claims.json",
    model=model,
    vocab=vocab,
    evidence_dict=evidence_data_tokens,
    save_path="../../data/dev-claims-predictions-lstm-batch.json"
)
# Out:
# Encoding evidences: 100%|██████████| 1181/1181 [02:23<00:00,  8.25it/s]
# Scoring claims: 100%|██████████| 154/154 [04:52<00:00,  1.90s/it]
# Prediction results saved to：../../data/dev-claims-predictions-lstm-batch.json

# %%
with open('../../data/dev-claims-predictions-lstm-batch.json', 'r') as f:
    result_data = json.load(f)
result_data
# Out:
# {'claim-752': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-320649',
#    'evidence-1196519',
#    'evidence-548766',
#    'evidence-34759']},
#  'claim-375': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-240308',
#    'evidence-477558']},
#  'claim-1266': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-939362',
#    'evidence-803857',
#    'evidence-34759',
#    'evidence-320649']},
#  'claim-871': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-477558',
#    'evidence-801082',
#    'evidence-777151',
#    'evidence-240308']},
#  'claim-2164': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-797505',
#    'evidence-118577',
#    'evidence-589349',
#    'evidence-1196519',
#    'evidence-240414',
#    'evidence-801082']},
#  'claim-1607': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-801082',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-548766',
#    'evidence-320649',
#    'evidence-34759']},
#  'claim-761': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-106073',
#    'evidence-240414',
#    'evidence-939362']},
#  'claim-1718': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-106073',
#    'evidence-540667',
#    'evidence-320649']},
#  'claim-1273': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-423643',
#    'evidence-262827',
#    'evidence-1196519',
#    'evidence-240308']},
#  'claim-1786': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-106073',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-251634']},
#  'claim-2796': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-240308',
#    'evidence-278454',
#    'evidence-1091781']},
#  'claim-2580': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-801082',
#    'evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-34759']},
#  'claim-1219': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-106073',
#    'evidence-801082',
#    'evidence-240308',
#    'evidence-34759']},
#  'claim-75': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-1196519',
#    'evidence-803857',
#    'evidence-278454',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1198843']},
#  'claim-2813': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-477558',
#    'evidence-540667',
#    'evidence-262827',
#    'evidence-971036']},
#  'claim-2335': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-278454',
#    'evidence-1198843']},
#  'claim-161': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-278454',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-477558',
#    'evidence-240308']},
#  'claim-2243': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-106073',
#    'evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-240308']},
#  'claim-1256': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-801082',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-797505',
#    'evidence-240414',
#    'evidence-240308']},
#  'claim-506': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-278454',
#    'evidence-1146282',
#    'evidence-1124385',
#    'evidence-240308',
#    'evidence-540667']},
#  'claim-369': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-817308',
#    'evidence-240414',
#    'evidence-1196519',
#    'evidence-589349',
#    'evidence-240308']},
#  'claim-2184': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-106073',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-797505',
#    'evidence-240414']},
#  'claim-1057': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-1198843',
#    'evidence-494148',
#    'evidence-1180647']},
#  'claim-104': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-548766',
#    'evidence-34759',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-251634']},
#  'claim-1975': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-1198843',
#    'evidence-477558']},
#  'claim-139': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-278454',
#    'evidence-423643',
#    'evidence-1198843',
#    'evidence-833557']},
#  'claim-2062': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-34759',
#    'evidence-1196519',
#    'evidence-106073',
#    'evidence-803857',
#    'evidence-278454']},
#  'claim-1160': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-106073',
#    'evidence-801082',
#    'evidence-803857',
#    'evidence-1196519',
#    'evidence-320649',
#    'evidence-548766']},
#  'claim-2679': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-278454']},
#  'claim-2662': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-240308',
#    'evidence-1180647',
#    'evidence-1196519',
#    'evidence-142343']},
#  'claim-1490': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-1180647',
#    'evidence-1146282',
#    'evidence-777151']},
#  'claim-2768': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-548766',
#    'evidence-801082',
#    'evidence-251634',
#    'evidence-106073',
#    'evidence-1196519',
#    'evidence-320649']},
#  'claim-2168': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-548766',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-797505']},
#  'claim-785': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-1196519',
#    'evidence-833557',
#    'evidence-534165',
#    'evidence-801082']},
#  'claim-2426': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-106073',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-34759',
#    'evidence-1198843',
#    'evidence-803857']},
#  'claim-1292': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-801082',
#    'evidence-240308',
#    'evidence-34759']},
#  'claim-993': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-1124385',
#    'evidence-1198843',
#    'evidence-833557']},
#  'claim-2593': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-1196519',
#    'evidence-1146282',
#    'evidence-278454']},
#  'claim-1567': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-251634',
#    'evidence-548766',
#    'evidence-1196519',
#    'evidence-34759',
#    'evidence-240308']},
#  'claim-1834': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-278454']},
#  'claim-856': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-1198843',
#    'evidence-494148',
#    'evidence-1196519',
#    'evidence-240308']},
#  'claim-540': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-1196519',
#    'evidence-106073',
#    'evidence-34759',
#    'evidence-240308',
#    'evidence-939362']},
#  'claim-757': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-142343',
#    'evidence-540667']},
#  'claim-1407': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-494148',
#    'evidence-423643',
#    'evidence-777151']},
#  'claim-3070': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-1196519',
#    'evidence-1180647',
#    'evidence-475808',
#    'evidence-240308']},
#  'claim-1745': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1196519',
#    'evidence-240308',
#    'evidence-803857',
#    'evidence-777151',
#    'evidence-494148',
#    'evidence-540667']},
#  'claim-1515': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-833557',
#    'evidence-494148',
#    'evidence-1196519',
#    'evidence-240308']},
#  'claim-1519': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-833557',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-1198843']},
#  'claim-3069': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-1198843',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-363469']},
#  'claim-677': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-240308',
#    'evidence-494148',
#    'evidence-1180647']},
#  'claim-765': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-423643',
#    'evidence-494148',
#    'evidence-1196519',
#    'evidence-801082']},
#  'claim-2275': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-435977',
#    'evidence-1196519',
#    'evidence-423643']},
#  'claim-1113': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-777151',
#    'evidence-1124385']},
#  'claim-2611': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1198843',
#    'evidence-548766',
#    'evidence-251634',
#    'evidence-1196519']},
#  'claim-2060': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-106073',
#    'evidence-1196519',
#    'evidence-34759',
#    'evidence-797505',
#    'evidence-118577',
#    'evidence-801082']},
#  'claim-2326': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-777151',
#    'evidence-801082']},
#  'claim-1087': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-240308',
#    'evidence-494148',
#    'evidence-1196519',
#    'evidence-540667']},
#  'claim-2867': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1198843',
#    'evidence-1196519',
#    'evidence-142343',
#    'evidence-1124385']},
#  'claim-2300': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-494148',
#    'evidence-833557',
#    'evidence-240308',
#    'evidence-435977']},
#  'claim-2250': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1198843',
#    'evidence-1196519',
#    'evidence-278454']},
#  'claim-2429': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-777151',
#    'evidence-801082']},
#  'claim-3051': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-833557',
#    'evidence-540667',
#    'evidence-1057998',
#    'evidence-240308',
#    'evidence-278454']},
#  'claim-1549': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-477558',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-971036',
#    'evidence-850174',
#    'evidence-106073']},
#  'claim-261': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-494148',
#    'evidence-1092520']},
#  'claim-2230': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1196519',
#    'evidence-803857',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-817308',
#    'evidence-540667']},
#  'claim-2579': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1196519',
#    'evidence-1198843',
#    'evidence-240308']},
#  'claim-1416': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-278454',
#    'evidence-540667',
#    'evidence-777151']},
#  'claim-2497': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-477558',
#    'evidence-106073',
#    'evidence-1196519',
#    'evidence-251634']},
#  'claim-811': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-278454',
#    'evidence-540667',
#    'evidence-1124385']},
#  'claim-1896': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-1180647',
#    'evidence-777151',
#    'evidence-142343']},
#  'claim-2819': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1196519',
#    'evidence-240308',
#    'evidence-803857',
#    'evidence-477558',
#    'evidence-278454',
#    'evidence-540667']},
#  'claim-2643': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-777151']},
#  'claim-1775': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-363469',
#    'evidence-435977',
#    'evidence-833557',
#    'evidence-1180647',
#    'evidence-1198843']},
#  'claim-316': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-477558',
#    'evidence-34759',
#    'evidence-106073',
#    'evidence-240308']},
#  'claim-896': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1180647',
#    'evidence-1196519',
#    'evidence-777151',
#    'evidence-262827']},
#  'claim-331': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-1198843',
#    'evidence-540667',
#    'evidence-278454']},
#  'claim-2574': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-1196519',
#    'evidence-251634',
#    'evidence-34759',
#    'evidence-939362']},
#  'claim-342': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-833557',
#    'evidence-278454',
#    'evidence-240308']},
#  'claim-2034': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-423643',
#    'evidence-494148']},
#  'claim-578': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-363469',
#    'evidence-540667',
#    'evidence-262827',
#    'evidence-1180647',
#    'evidence-240308']},
#  'claim-976': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1196519',
#    'evidence-534165',
#    'evidence-106073']},
#  'claim-1097': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-833557']},
#  'claim-609': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-777151',
#    'evidence-240308',
#    'evidence-1124385',
#    'evidence-240414']},
#  'claim-173': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-939362',
#    'evidence-803857',
#    'evidence-850174',
#    'evidence-34759']},
#  'claim-1222': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-817308',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-240414']},
#  'claim-2441': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-494148',
#    'evidence-817308',
#    'evidence-240414']},
#  'claim-756': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-1180647',
#    'evidence-540667',
#    'evidence-240308',
#    'evidence-1196519']},
#  'claim-2577': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-540667',
#    'evidence-494148',
#    'evidence-833557',
#    'evidence-477558']},
#  'claim-2890': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-106073',
#    'evidence-801082',
#    'evidence-803857',
#    'evidence-971036',
#    'evidence-939362',
#    'evidence-251634']},
#  'claim-2478': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-1198843']},
#  'claim-2399': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-363469',
#    'evidence-1196519',
#    'evidence-423643',
#    'evidence-833557']},
#  'claim-3091': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-106073',
#    'evidence-278454',
#    'evidence-240308',
#    'evidence-34759']},
#  'claim-141': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-363469',
#    'evidence-1198843',
#    'evidence-1196519']},
#  'claim-1933': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-477558',
#    'evidence-1198843',
#    'evidence-540667',
#    'evidence-534165']},
#  'claim-1689': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-34759',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-240414']},
#  'claim-443': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-477558',
#    'evidence-278454',
#    'evidence-540667']},
#  'claim-2037': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-278454',
#    'evidence-801082',
#    'evidence-423643',
#    'evidence-320649',
#    'evidence-540667']},
#  'claim-1734': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-801082',
#    'evidence-142343',
#    'evidence-540667',
#    'evidence-477558']},
#  'claim-2093': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1146282',
#    'evidence-106073']},
#  'claim-1400': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-803857',
#    'evidence-106073',
#    'evidence-971036',
#    'evidence-299025',
#    'evidence-540667']},
#  'claim-1638': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-1196519',
#    'evidence-240308',
#    'evidence-803857',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-797505']},
#  'claim-3075': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-817308',
#    'evidence-240414']},
#  'claim-38': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-817308',
#    'evidence-777151',
#    'evidence-363469']},
#  'claim-1643': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-625563',
#    'evidence-363469',
#    'evidence-777151']},
#  'claim-1259': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-1180647',
#    'evidence-833557',
#    'evidence-435977',
#    'evidence-1196519']},
#  'claim-1605': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-1196519',
#    'evidence-797505',
#    'evidence-803857',
#    'evidence-240308',
#    'evidence-801082',
#    'evidence-589349']},
#  'claim-1711': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-477558',
#    'evidence-106073',
#    'evidence-278454',
#    'evidence-801082']},
#  'claim-2236': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1198843']},
#  'claim-1040': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-494148',
#    'evidence-777151',
#    'evidence-1124385']},
#  'claim-392': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-803857',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-251634',
#    'evidence-278454']},
#  'claim-368': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-777151',
#    'evidence-540667',
#    'evidence-278454']},
#  'claim-559': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-278454',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-477558',
#    'evidence-803857',
#    'evidence-240308']},
#  'claim-2583': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-801082',
#    'evidence-803857',
#    'evidence-548766',
#    'evidence-320649',
#    'evidence-106073',
#    'evidence-1196519']},
#  'claim-2609': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-278454',
#    'evidence-1180647',
#    'evidence-1124385']},
#  'claim-492': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-278454',
#    'evidence-777151',
#    'evidence-240414']},
#  'claim-1420': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-540667',
#    'evidence-801082',
#    'evidence-240308']},
#  'claim-1089': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-817308',
#    'evidence-1196519',
#    'evidence-777151',
#    'evidence-1124385']},
#  'claim-1467': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-540667',
#    'evidence-34759']},
#  'claim-444': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-106073',
#    'evidence-801082',
#    'evidence-850174',
#    'evidence-939362',
#    'evidence-477558',
#    'evidence-540667']},
#  'claim-803': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-1198843',
#    'evidence-278454',
#    'evidence-1196519']},
#  'claim-1668': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-797505',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-589349',
#    'evidence-801082',
#    'evidence-169769']},
#  'claim-742': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-363469',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-240308']},
#  'claim-846': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-1180647',
#    'evidence-1124385',
#    'evidence-540667']},
#  'claim-2119': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-477558',
#    'evidence-850174',
#    'evidence-971036',
#    'evidence-320649',
#    'evidence-803857']},
#  'claim-1167': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1198843']},
#  'claim-623': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-106073',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1196519',
#    'evidence-363469']},
#  'claim-2882': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-540667',
#    'evidence-278454',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-833557']},
#  'claim-1698': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1196519',
#    'evidence-240308',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-803857',
#    'evidence-477558']},
#  'claim-181': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-34759',
#    'evidence-803857',
#    'evidence-1196519',
#    'evidence-540667']},
#  'claim-281': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-106073',
#    'evidence-801082']},
#  'claim-2809': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1198843',
#    'evidence-240308',
#    'evidence-540667',
#    'evidence-363469',
#    'evidence-142343']},
#  'claim-1928': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-1196519',
#    'evidence-106073',
#    'evidence-797505',
#    'evidence-801082',
#    'evidence-240308',
#    'evidence-803857']},
#  'claim-2787': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-540667',
#    'evidence-1196519']},
#  'claim-478': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-477558',
#    'evidence-299025',
#    'evidence-817759']},
#  'claim-988': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-801082',
#    'evidence-548766',
#    'evidence-251634',
#    'evidence-803857',
#    'evidence-106073',
#    'evidence-320649']},
#  'claim-266': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-1198843',
#    'evidence-801082',
#    'evidence-278454']},
#  'claim-2282': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-801082',
#    'evidence-320649',
#    'evidence-106073',
#    'evidence-251634',
#    'evidence-803857',
#    'evidence-1196519']},
#  'claim-2895': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-278454',
#    'evidence-477558',
#    'evidence-540667']},
#  'claim-349': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-548766',
#    'evidence-34759',
#    'evidence-939362',
#    'evidence-803857',
#    'evidence-1196519']},
#  'claim-2101': {'claim_label': 'DISPUTED',
#   'evidences': ['evidence-801082',
#    'evidence-106073',
#    'evidence-548766',
#    'evidence-850174',
#    'evidence-939362',
#    'evidence-320649']},
#  'claim-897': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-801082',
#    'evidence-777151']},
#  'claim-3063': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-106073',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-803857',
#    'evidence-320649',
#    'evidence-797505']},
#  'claim-386': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-1180647',
#    'evidence-1091781',
#    'evidence-494148',
#    'evidence-833557']},
#  'claim-2691': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-540667',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-34759']},
#  'claim-530': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-801082',
#    'evidence-320649',
#    'evidence-1198843',
#    'evidence-278454']},
#  'claim-2979': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-363469',
#    'evidence-540667',
#    'evidence-106073',
#    'evidence-1196519',
#    'evidence-477558']},
#  'claim-665': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-1180647',
#    'evidence-1124385',
#    'evidence-1091781',
#    'evidence-833557',
#    'evidence-28478']},
#  'claim-199': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-801082',
#    'evidence-1196519',
#    'evidence-278454',
#    'evidence-803857',
#    'evidence-106073',
#    'evidence-240308']},
#  'claim-490': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-240308',
#    'evidence-1196519',
#    'evidence-540667',
#    'evidence-494148',
#    'evidence-278454']},
#  'claim-2400': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-777151',
#    'evidence-240308',
#    'evidence-363469',
#    'evidence-540667']},
#  'claim-204': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-278454',
#    'evidence-34759',
#    'evidence-240308',
#    'evidence-1196519']},
#  'claim-1426': {'claim_label': 'NOT_ENOUGH_INFO',
#   'evidences': ['evidence-803857',
#    'evidence-801082',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-1198843',
#    'evidence-540667']},
#  'claim-698': {'claim_label': 'REFUTES',
#   'evidences': ['evidence-803857',
#    'evidence-1124385',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-1196519',
#    'evidence-262827']},
#  'claim-1021': {'claim_label': 'SUPPORTS',
#   'evidences': ['evidence-803857',
#    'evidence-1196519',
#    'evidence-240308',
#    'evidence-777151',
#    'evidence-540667',
#    'evidence-363469']}}

# %%
# !python ../../eval.py \
  --predictions ../../data/dev-claims-predictions-lstm-batch.json \
  --groundtruth ../../data/dev-claims.json
# Out:
# Evidence Retrieval F-score (F)    = 0.0018552875695732837
# Claim Classification Accuracy (A) = 1.0
# Harmonic Mean of F and A          = 0.0037037037037037034

# %%
import json

with open("../../data/dev-claims-predictions-lstm-batch.json", 'r') as f:
    preds = json.load(f)

with open("../../data/dev-claims.json", 'r') as f:
    truth = json.load(f)

for cid in preds:
    print("CLAIM:", truth[cid]["claim_text"])
    print("True evidence:", truth[cid]["evidences"])
    print("Predicted:", preds[cid]["evidences"])
    break
# Out:
# CLAIM: [South Australia] has the most expensive electricity in the world.
# True evidence: ['evidence-67732', 'evidence-572512']
# Predicted: ['evidence-801082', 'evidence-106073', 'evidence-320649', 'evidence-1196519', 'evidence-548766', 'evidence-34759']

# %% [markdown]
# ## Object Oriented Programming codes here
#
# *You can use multiple code snippets. Just add more if needed*
